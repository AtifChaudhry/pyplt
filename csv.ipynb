# %%
# For more information on pyplot: https://matplotlib.org/3.1.1/tutorials/#


import csv
import matplotlib.pyplot as plt
x, y = [], []
with open('file.csv') as csvDataFile:
    for row in csv.reader(csvDataFile):
        x.append(float(row[0]))
        y.append(float(row[1]))
plt.scatter(x,y)
plt.plot(x,y)
plt.xlabel('Time')
plt.ylabel('Memory Usage')
plt.show()
print('x=',x)
print('y=',y)
# Out:
# x= [1.0, 4.0, 6.0, 9.0]
# y= [20.0, 21.0, 33.0, 21.0]
